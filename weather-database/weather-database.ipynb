# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time
from scipy.stats import linregress

# %%
# Initialize Lists, Counters, and Variables
cities = []
city_data = []
record_count = 1
set_count = 1
url = f'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}'

# Print the beginning of the logging.
print(f'Beginning Data Retrieval')
print('-------------------------')
# Out:
# Beginning Data Retrieval
# -------------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90,90,size=1700)
lngs = np.random.uniform(-180,180,size=1700)
lat_lngs = zip(lats, lngs)
coords = list(lat_lngs)

# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0],coord[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 686

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = f'{url}&q={city.replace(" ","")}'
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | hutchinson
# Processing Record 5 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 6 of Set 1 | victoria
# Processing Record 7 of Set 1 | constitucion
# Processing Record 8 of Set 1 | bonavista
# Processing Record 9 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 12 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 13 of Set 1 | fort nelson
# City not found. Skipping...
# Processing Record 14 of Set 1 | namatanai
# Processing Record 15 of Set 1 | bilibino
# Processing Record 16 of Set 1 | llandrindod wells
# City not found. Skipping...
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | mayo
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | almeirim
# Processing Record 31 of Set 1 | angoche
# Processing Record 32 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 33 of Set 1 | saskylakh
# Processing Record 34 of Set 1 | cayenne
# Processing Record 35 of Set 1 | bambous virieux
# City not found. Skipping...
# Processing Record 36 of Set 1 | kudahuvadhoo
# Processing Record 37 of Set 1 | bayir
# Processing Record 38 of Set 1 | arlit
# Processing Record 39 of Set 1 | cabo san lucas
# City not found. Skipping...
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | pacific grove
# City not found. Skipping...
# Processing Record 42 of Set 1 | manokwari
# Processing Record 43 of Set 1 | baisha
# Processing Record 44 of Set 1 | nanortalik
# Processing Record 45 of Set 1 | chiang khong
# City not found. Skipping...
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | tual
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | berlevag
# Processing Record 1 of Set 2 | te anau
# City not found. Skipping...
# Processing Record 2 of Set 2 | camacha
# Processing Record 3 of Set 2 | mangan
# Processing Record 4 of Set 2 | lensk
# Processing Record 5 of Set 2 | rosario
# Processing Record 6 of Set 2 | cervo
# Processing Record 7 of Set 2 | genhe
# Processing Record 8 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 2 | sur
# Processing Record 10 of Set 2 | kaitangata
# Processing Record 11 of Set 2 | bengkulu
# Processing Record 12 of Set 2 | iqaluit
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | yialos
# City not found. Skipping...
# Processing Record 15 of Set 2 | beringovskiy
# Processing Record 16 of Set 2 | barquisimeto
# Processing Record 17 of Set 2 | cherskiy
# Processing Record 18 of Set 2 | pristina
# Processing Record 19 of Set 2 | ribeira grande
# City not found. Skipping...
# Processing Record 20 of Set 2 | aginskoye
# Processing Record 21 of Set 2 | qandala
# Processing Record 22 of Set 2 | vao
# Processing Record 23 of Set 2 | wageningen
# Processing Record 24 of Set 2 | abu kamal
# City not found. Skipping...
# Processing Record 25 of Set 2 | zalantun
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | codrington
# Processing Record 29 of Set 2 | belaya gora
# City not found. Skipping...
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 2 | tuatapere
# Processing Record 36 of Set 2 | paamiut
# Processing Record 37 of Set 2 | klaksvik
# Processing Record 38 of Set 2 | itarema
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | sishui
# Processing Record 41 of Set 2 | colares
# Processing Record 42 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | dehloran
# Processing Record 45 of Set 2 | barcelona
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | lebu
# Processing Record 48 of Set 2 | buala
# Processing Record 49 of Set 2 | gerash
# Processing Record 50 of Set 2 | toamasina
# Processing Record 1 of Set 3 | tournon-sur-rhone
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | puerto ayora
# City not found. Skipping...
# Processing Record 5 of Set 3 | codo
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | airai
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | hilo
# Processing Record 10 of Set 3 | half moon bay
# City not found. Skipping...
# Processing Record 11 of Set 3 | naliya
# Processing Record 12 of Set 3 | sinnamary
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | pirapemas
# Processing Record 15 of Set 3 | qingdao
# Processing Record 16 of Set 3 | karpathos
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | salcininkai
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | coquimbo
# Processing Record 21 of Set 3 | skorodnoye
# Processing Record 22 of Set 3 | vila velha
# City not found. Skipping...
# Processing Record 23 of Set 3 | ostrovnoy
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | husavik
# Processing Record 26 of Set 3 | kurilsk
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 3 | missoula
# Processing Record 30 of Set 3 | xining
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | port hedland
# City not found. Skipping...
# Processing Record 33 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 3 | chapais
# Processing Record 35 of Set 3 | tautira
# Processing Record 36 of Set 3 | port hardy
# City not found. Skipping...
# Processing Record 37 of Set 3 | awbari
# Processing Record 38 of Set 3 | strezhevoy
# Processing Record 39 of Set 3 | champerico
# Processing Record 40 of Set 3 | inuvik
# Processing Record 41 of Set 3 | kavieng
# Processing Record 42 of Set 3 | aklavik
# Processing Record 43 of Set 3 | seoul
# Processing Record 44 of Set 3 | kargasok
# Processing Record 45 of Set 3 | mulege
# Processing Record 46 of Set 3 | qaanaaq
# Processing Record 47 of Set 3 | bathsheba
# Processing Record 48 of Set 3 | samarai
# Processing Record 49 of Set 3 | mnogovershinnyy
# Processing Record 50 of Set 3 | komsomolskiy
# Processing Record 1 of Set 4 | pangody
# Processing Record 2 of Set 4 | bereda
# Processing Record 3 of Set 4 | san policarpo
# City not found. Skipping...
# Processing Record 4 of Set 4 | east london
# City not found. Skipping...
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | zyryanka
# Processing Record 7 of Set 4 | la palma
# City not found. Skipping...
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | erzin
# Processing Record 10 of Set 4 | rocha
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | san patricio
# City not found. Skipping...
# Processing Record 13 of Set 4 | krasnovishersk
# Processing Record 14 of Set 4 | burlington
# Processing Record 15 of Set 4 | coahuayana
# Processing Record 16 of Set 4 | voyvozh
# Processing Record 17 of Set 4 | nemuro
# Processing Record 18 of Set 4 | port moresby
# City not found. Skipping...
# Processing Record 19 of Set 4 | touros
# Processing Record 20 of Set 4 | kaeo
# Processing Record 21 of Set 4 | chipinge
# Processing Record 22 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 4 | sikonge
# Processing Record 24 of Set 4 | longyan
# Processing Record 25 of Set 4 | saldanha
# Processing Record 26 of Set 4 | jalalabad
# Processing Record 27 of Set 4 | batagay-alyta
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | takaka
# Processing Record 30 of Set 4 | havoysund
# Processing Record 31 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 4 | naze
# Processing Record 34 of Set 4 | mar del plata
# City not found. Skipping...
# Processing Record 35 of Set 4 | fairfield
# Processing Record 36 of Set 4 | hovd
# Processing Record 37 of Set 4 | pointe-noire
# Processing Record 38 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 4 | urulga
# City not found. Skipping...
# Processing Record 40 of Set 4 | kalmunai
# Processing Record 41 of Set 4 | fredericksburg
# Processing Record 42 of Set 4 | alta floresta
# City not found. Skipping...
# Processing Record 43 of Set 4 | savonlinna
# Processing Record 44 of Set 4 | sidmouth
# Processing Record 45 of Set 4 | nakusp
# Processing Record 46 of Set 4 | praia da vitoria
# City not found. Skipping...
# Processing Record 47 of Set 4 | dwarka
# Processing Record 48 of Set 4 | pasni
# Processing Record 49 of Set 4 | farsund
# Processing Record 50 of Set 4 | provideniya
# Processing Record 1 of Set 5 | ponta do sol
# City not found. Skipping...
# Processing Record 2 of Set 5 | severo-kurilsk
# Processing Record 3 of Set 5 | souillac
# Processing Record 4 of Set 5 | maumere
# Processing Record 5 of Set 5 | midland
# Processing Record 6 of Set 5 | road town
# City not found. Skipping...
# Processing Record 7 of Set 5 | norman wells
# City not found. Skipping...
# Processing Record 8 of Set 5 | gorontalo
# Processing Record 9 of Set 5 | san cristobal
# City not found. Skipping...
# Processing Record 10 of Set 5 | traverse city
# City not found. Skipping...
# Processing Record 11 of Set 5 | jacobabad
# Processing Record 12 of Set 5 | chuy
# Processing Record 13 of Set 5 | vostok
# Processing Record 14 of Set 5 | voh
# Processing Record 15 of Set 5 | sakakah
# Processing Record 16 of Set 5 | talnakh
# Processing Record 17 of Set 5 | santa fe
# City not found. Skipping...
# Processing Record 18 of Set 5 | oksfjord
# Processing Record 19 of Set 5 | conakry
# Processing Record 20 of Set 5 | melito di porto salvo
# City not found. Skipping...
# Processing Record 21 of Set 5 | tazovskiy
# Processing Record 22 of Set 5 | oskemen
# Processing Record 23 of Set 5 | isangel
# Processing Record 24 of Set 5 | clyde river
# City not found. Skipping...
# Processing Record 25 of Set 5 | vestmanna
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | georgetown
# Processing Record 28 of Set 5 | haag
# Processing Record 29 of Set 5 | san andres
# City not found. Skipping...
# Processing Record 30 of Set 5 | hailey
# Processing Record 31 of Set 5 | arraial do cabo
# City not found. Skipping...
# Processing Record 32 of Set 5 | domoni
# Processing Record 33 of Set 5 | along
# Processing Record 34 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 35 of Set 5 | roald
# Processing Record 36 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 5 | eyl
# Processing Record 38 of Set 5 | lavrentiya
# Processing Record 39 of Set 5 | capim grosso
# City not found. Skipping...
# Processing Record 40 of Set 5 | cocobeach
# Processing Record 41 of Set 5 | nabire
# Processing Record 42 of Set 5 | flinders
# Processing Record 43 of Set 5 | aljezur
# Processing Record 44 of Set 5 | avera
# Processing Record 45 of Set 5 | madimba
# Processing Record 46 of Set 5 | kovdor
# Processing Record 47 of Set 5 | sechura
# Processing Record 48 of Set 5 | kenai
# Processing Record 49 of Set 5 | rafaela
# Processing Record 50 of Set 5 | micheweni
# Processing Record 1 of Set 6 | talara
# Processing Record 2 of Set 6 | ancud
# Processing Record 3 of Set 6 | balakovo
# Processing Record 4 of Set 6 | salalah
# Processing Record 5 of Set 6 | kemijarvi
# Processing Record 6 of Set 6 | brokopondo
# Processing Record 7 of Set 6 | zyryanovsk
# Processing Record 8 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 6 | antri
# Processing Record 10 of Set 6 | manggar
# Processing Record 11 of Set 6 | fuerte olimpo
# City not found. Skipping...
# Processing Record 12 of Set 6 | wajima
# Processing Record 13 of Set 6 | port macquarie
# City not found. Skipping...
# Processing Record 14 of Set 6 | poya
# Processing Record 15 of Set 6 | caxito
# Processing Record 16 of Set 6 | farafangana
# Processing Record 17 of Set 6 | bagdarin
# Processing Record 18 of Set 6 | dromolaxia
# Processing Record 19 of Set 6 | pudozh
# Processing Record 20 of Set 6 | kyshtovka
# Processing Record 21 of Set 6 | sandpoint
# Processing Record 22 of Set 6 | oranjemund
# Processing Record 23 of Set 6 | seddon
# Processing Record 24 of Set 6 | apaxtla
# City not found. Skipping...
# Processing Record 25 of Set 6 | thinadhoo
# Processing Record 26 of Set 6 | meulaboh
# Processing Record 27 of Set 6 | ilulissat
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | saint-philippe
# Processing Record 30 of Set 6 | atar
# Processing Record 31 of Set 6 | labuan
# Processing Record 32 of Set 6 | bauchi
# Processing Record 33 of Set 6 | udachnyy
# Processing Record 34 of Set 6 | filadelfia
# Processing Record 35 of Set 6 | hami
# Processing Record 36 of Set 6 | jablah
# Processing Record 37 of Set 6 | truckee
# Processing Record 38 of Set 6 | monastyryshche
# Processing Record 39 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 40 of Set 6 | pisco
# Processing Record 41 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 6 | evensk
# Processing Record 43 of Set 6 | riverton
# Processing Record 44 of Set 6 | srikakulam
# Processing Record 45 of Set 6 | santiago del estero
# City not found. Skipping...
# Processing Record 46 of Set 6 | kapaa
# Processing Record 47 of Set 6 | laguna
# Processing Record 48 of Set 6 | shu
# Processing Record 49 of Set 6 | ampanihy
# Processing Record 50 of Set 6 | mandalgovi
# Processing Record 1 of Set 7 | kununurra
# Processing Record 2 of Set 7 | samana
# Processing Record 3 of Set 7 | port-gentil
# Processing Record 4 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 7 | ambilobe
# Processing Record 6 of Set 7 | itoman
# Processing Record 7 of Set 7 | todos santos
# City not found. Skipping...
# Processing Record 8 of Set 7 | shahrud
# Processing Record 9 of Set 7 | saint george
# City not found. Skipping...
# Processing Record 10 of Set 7 | chilca
# Processing Record 11 of Set 7 | lukovetskiy
# Processing Record 12 of Set 7 | saint-pierre
# Processing Record 13 of Set 7 | moussoro
# Processing Record 14 of Set 7 | alofi
# Processing Record 15 of Set 7 | trelew
# Processing Record 16 of Set 7 | sobolevo
# Processing Record 17 of Set 7 | alice springs
# City not found. Skipping...
# Processing Record 18 of Set 7 | panchgani
# Processing Record 19 of Set 7 | ipora
# Processing Record 20 of Set 7 | tromso
# Processing Record 21 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 7 | bratslav
# Processing Record 23 of Set 7 | wexford
# Processing Record 24 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 25 of Set 7 | gazojak
# Processing Record 26 of Set 7 | pilao arcado
# City not found. Skipping...
# Processing Record 27 of Set 7 | paris
# Processing Record 28 of Set 7 | lowestoft
# Processing Record 29 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 7 | dakar
# Processing Record 31 of Set 7 | carmarthen
# Processing Record 32 of Set 7 | methven
# Processing Record 33 of Set 7 | lafiagi
# Processing Record 34 of Set 7 | watertown
# Processing Record 35 of Set 7 | spasskoye
# Processing Record 36 of Set 7 | lasa
# Processing Record 37 of Set 7 | shingu
# Processing Record 38 of Set 7 | mount isa
# City not found. Skipping...
# Processing Record 39 of Set 7 | kieta
# Processing Record 40 of Set 7 | repelon
# Processing Record 41 of Set 7 | cloquet
# Processing Record 42 of Set 7 | liku
# Processing Record 43 of Set 7 | santa marta
# City not found. Skipping...
# Processing Record 44 of Set 7 | karaton
# Processing Record 45 of Set 7 | noumea
# Processing Record 46 of Set 7 | tema
# Processing Record 47 of Set 7 | katsuura
# Processing Record 48 of Set 7 | grimmen
# Processing Record 49 of Set 7 | sitka
# Processing Record 50 of Set 7 | rudbar
# Processing Record 1 of Set 8 | boyolangu
# Processing Record 2 of Set 8 | longyearbyen
# Processing Record 3 of Set 8 | sudislavl
# Processing Record 4 of Set 8 | goba
# Processing Record 5 of Set 8 | buin
# Processing Record 6 of Set 8 | kiama
# Processing Record 7 of Set 8 | wattegama
# Processing Record 8 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 8 | eyemouth
# Processing Record 10 of Set 8 | gillette
# Processing Record 11 of Set 8 | tarko-sale
# Processing Record 12 of Set 8 | shumskiy
# Processing Record 13 of Set 8 | bielsk podlaski
# City not found. Skipping...
# Processing Record 14 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 15 of Set 8 | biak
# Processing Record 16 of Set 8 | sotouboua
# Processing Record 17 of Set 8 | kralendijk
# Processing Record 18 of Set 8 | havelock
# Processing Record 19 of Set 8 | ajaccio
# Processing Record 20 of Set 8 | adrar
# Processing Record 21 of Set 8 | sao filipe
# City not found. Skipping...
# Processing Record 22 of Set 8 | sayansk
# Processing Record 23 of Set 8 | obo
# Processing Record 24 of Set 8 | pierre
# Processing Record 25 of Set 8 | irricana
# Processing Record 26 of Set 8 | christchurch
# Processing Record 27 of Set 8 | mackay
# Processing Record 28 of Set 8 | ixtapa
# Processing Record 29 of Set 8 | ukiah
# Processing Record 30 of Set 8 | santa rosa
# Processing Record 31 of Set 8 | naryan-mar
# Processing Record 32 of Set 8 | zorgo
# Processing Record 33 of Set 8 | arklow
# Processing Record 34 of Set 8 | tartagal
# Processing Record 35 of Set 8 | sotik
# Processing Record 36 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 37 of Set 8 | buluang
# Processing Record 38 of Set 8 | esperance
# Processing Record 39 of Set 8 | kruisfontein
# Processing Record 40 of Set 8 | huarmey
# Processing Record 41 of Set 8 | bac lieu
# City not found. Skipping...
# Processing Record 42 of Set 8 | jomalig
# City not found. Skipping...
# Processing Record 43 of Set 8 | atasu
# Processing Record 44 of Set 8 | yanji
# Processing Record 45 of Set 8 | leeton
# Processing Record 46 of Set 8 | disraeli
# Processing Record 47 of Set 8 | hofn
# Processing Record 48 of Set 8 | havre-saint-pierre
# Processing Record 49 of Set 8 | yerbogachen
# Processing Record 50 of Set 8 | nantucket
# Processing Record 1 of Set 9 | yar-sale
# Processing Record 2 of Set 9 | russell
# Processing Record 3 of Set 9 | venado tuerto
# City not found. Skipping...
# Processing Record 4 of Set 9 | chicama
# Processing Record 5 of Set 9 | temiscaming
# Processing Record 6 of Set 9 | najran
# Processing Record 7 of Set 9 | asau
# Processing Record 8 of Set 9 | egvekinot
# Processing Record 9 of Set 9 | kousseri
# Processing Record 10 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 9 | umm lajj
# City not found. Skipping...
# Processing Record 12 of Set 9 | rudnogorsk
# Processing Record 13 of Set 9 | batagay
# Processing Record 14 of Set 9 | kavaratti
# Processing Record 15 of Set 9 | san quintin
# City not found. Skipping...
# Processing Record 16 of Set 9 | kirkland lake
# City not found. Skipping...
# Processing Record 17 of Set 9 | dorgos
# Processing Record 18 of Set 9 | niquero
# Processing Record 19 of Set 9 | morant bay
# City not found. Skipping...
# Processing Record 20 of Set 9 | dalvik
# Processing Record 21 of Set 9 | manta
# Processing Record 22 of Set 9 | jalu
# Processing Record 23 of Set 9 | safaqis
# City not found. Skipping...
# Processing Record 24 of Set 9 | uzumlu
# City not found. Skipping...
# Processing Record 25 of Set 9 | pumiao
# Processing Record 26 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 9 | scarborough
# Processing Record 28 of Set 9 | yenagoa
# Processing Record 29 of Set 9 | bairiki
# Processing Record 30 of Set 9 | babaeski
# Processing Record 31 of Set 9 | riyadh
# Processing Record 32 of Set 9 | coffs harbour
# City not found. Skipping...
# Processing Record 33 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 9 | lorengau
# Processing Record 35 of Set 9 | igarka
# Processing Record 36 of Set 9 | kirakira
# Processing Record 37 of Set 9 | altay
# Processing Record 38 of Set 9 | caravelas
# Processing Record 39 of Set 9 | loubomo
# Processing Record 40 of Set 9 | tacuarembo
# Processing Record 41 of Set 9 | eureka
# Processing Record 42 of Set 9 | muros
# Processing Record 43 of Set 9 | khani
# Processing Record 44 of Set 9 | mazagao
# Processing Record 45 of Set 9 | marsa matruh
# City not found. Skipping...
# Processing Record 46 of Set 9 | port lincoln
# City not found. Skipping...
# Processing Record 47 of Set 9 | skelleftea
# Processing Record 48 of Set 9 | ankazoabo
# Processing Record 49 of Set 9 | shache
# Processing Record 50 of Set 9 | ojinaga
# Processing Record 1 of Set 10 | gonc
# Processing Record 2 of Set 10 | vanavara
# Processing Record 3 of Set 10 | torrington
# Processing Record 4 of Set 10 | tateyama
# Processing Record 5 of Set 10 | pafos
# Processing Record 6 of Set 10 | santa maria
# City not found. Skipping...
# Processing Record 7 of Set 10 | galeana
# Processing Record 8 of Set 10 | hidalgotitlan
# Processing Record 9 of Set 10 | raudeberg
# Processing Record 10 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 11 of Set 10 | tiznit
# Processing Record 12 of Set 10 | gitega
# Processing Record 13 of Set 10 | namie
# Processing Record 14 of Set 10 | athabasca
# Processing Record 15 of Set 10 | hare bay
# City not found. Skipping...
# Processing Record 16 of Set 10 | la ronge
# City not found. Skipping...
# Processing Record 17 of Set 10 | washington
# Processing Record 18 of Set 10 | xingyi
# Processing Record 19 of Set 10 | bolonchen
# City not found. Skipping...
# Processing Record 20 of Set 10 | ayer tawar
# City not found. Skipping...
# Processing Record 21 of Set 10 | axim
# Processing Record 22 of Set 10 | saint-augustin
# Processing Record 23 of Set 10 | winnemucca
# Processing Record 24 of Set 10 | kurchum
# Processing Record 25 of Set 10 | mezen
# Processing Record 26 of Set 10 | sao geraldo do araguaia
# City not found. Skipping...
# Processing Record 27 of Set 10 | esmeraldas
# Processing Record 28 of Set 10 | steinbach
# Processing Record 29 of Set 10 | nadym
# Processing Record 30 of Set 10 | marathon
# Processing Record 31 of Set 10 | sao gabriel da cachoeira
# City not found. Skipping...
# Processing Record 32 of Set 10 | kodiak
# Processing Record 33 of Set 10 | port blair
# City not found. Skipping...
# Processing Record 34 of Set 10 | gubbi
# Processing Record 35 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 36 of Set 10 | ornskoldsvik
# Processing Record 37 of Set 10 | bartoszyce
# Processing Record 38 of Set 10 | namibe
# Processing Record 39 of Set 10 | luderitz
# Processing Record 40 of Set 10 | bilgoraj
# Processing Record 41 of Set 10 | nouakchott
# Processing Record 42 of Set 10 | nicoya
# Processing Record 43 of Set 10 | inhambane
# Processing Record 44 of Set 10 | kijang
# Processing Record 45 of Set 10 | zhanakorgan
# Processing Record 46 of Set 10 | kayerkan
# Processing Record 47 of Set 10 | quelimane
# Processing Record 48 of Set 10 | francistown
# Processing Record 49 of Set 10 | aksu
# Processing Record 50 of Set 10 | gamay
# Processing Record 1 of Set 11 | south venice
# City not found. Skipping...
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | bandarbeyla
# Processing Record 4 of Set 11 | grindavik
# Processing Record 5 of Set 11 | dabhoi
# Processing Record 6 of Set 11 | fort-shevchenko
# Processing Record 7 of Set 11 | varangaon
# Processing Record 8 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 11 | pangai
# Processing Record 10 of Set 11 | wa
# City not found. Skipping...
# Processing Record 11 of Set 11 | sita road
# City not found. Skipping...
# Processing Record 12 of Set 11 | penzance
# Processing Record 13 of Set 11 | los angeles
# City not found. Skipping...
# Processing Record 14 of Set 11 | russkiy kameshkir
# City not found. Skipping...
# Processing Record 15 of Set 11 | martinez
# Processing Record 16 of Set 11 | pontes e lacerda
# City not found. Skipping...
# Processing Record 17 of Set 11 | bonthe
# Processing Record 18 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 11 | baoying
# Processing Record 20 of Set 11 | ryazan
# Processing Record 21 of Set 11 | betare oya
# City not found. Skipping...
# Processing Record 22 of Set 11 | mehran
# Processing Record 23 of Set 11 | chai nat
# Processing Record 24 of Set 11 | erdaojiang
# Processing Record 25 of Set 11 | leningradskiy
# Processing Record 26 of Set 11 | nimaparha
# Processing Record 27 of Set 11 | arman
# Processing Record 28 of Set 11 | los llanos de aridane
# City not found. Skipping...
# Processing Record 29 of Set 11 | bambanglipuro
# Processing Record 30 of Set 11 | ericeira
# Processing Record 31 of Set 11 | vardo
# Processing Record 32 of Set 11 | blagoyevo
# Processing Record 33 of Set 11 | edd
# Processing Record 34 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 11 | pascagoula
# Processing Record 36 of Set 11 | gaoyou
# Processing Record 37 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 38 of Set 11 | kiunga
# Processing Record 39 of Set 11 | zabol
# Processing Record 40 of Set 11 | bafq
# Processing Record 41 of Set 11 | guerrero negro
# City not found. Skipping...
# Processing Record 42 of Set 11 | itatiba
# Processing Record 43 of Set 11 | richards bay
# City not found. Skipping...
# Processing Record 44 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 45 of Set 11 | imbituba
# Processing Record 46 of Set 11 | boguchany
# Processing Record 47 of Set 11 | westport
# Processing Record 48 of Set 11 | isla mujeres
# City not found. Skipping...
# Processing Record 49 of Set 11 | fairbanks
# Processing Record 50 of Set 11 | swakopmund
# Processing Record 1 of Set 12 | muyezerskiy
# Processing Record 2 of Set 12 | yuxia
# Processing Record 3 of Set 12 | bajil
# Processing Record 4 of Set 12 | lagoa
# Processing Record 5 of Set 12 | bahia honda
# City not found. Skipping...
# Processing Record 6 of Set 12 | mantua
# Processing Record 7 of Set 12 | mount gambier
# City not found. Skipping...
# Processing Record 8 of Set 12 | coari
# Processing Record 9 of Set 12 | ejido
# Processing Record 10 of Set 12 | la maddalena
# City not found. Skipping...
# Processing Record 11 of Set 12 | tatarsk
# Processing Record 12 of Set 12 | cuiluan
# Processing Record 13 of Set 12 | clonakilty
# Processing Record 14 of Set 12 | alyangula
# Processing Record 15 of Set 12 | brae
# Processing Record 16 of Set 12 | pampa
# Processing Record 17 of Set 12 | gonbad-e qabus
# City not found. Skipping...
# Processing Record 18 of Set 12 | alexandria
# Processing Record 19 of Set 12 | clearwater
# Processing Record 20 of Set 12 | doha
# Processing Record 21 of Set 12 | vanimo
# Processing Record 22 of Set 12 | rantepao
# Processing Record 23 of Set 12 | victor harbor
# City not found. Skipping...
# Processing Record 24 of Set 12 | trincomalee
# Processing Record 25 of Set 12 | buraydah
# Processing Record 26 of Set 12 | melissourgoi
# City not found. Skipping...
# Processing Record 27 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 28 of Set 12 | galle
# Processing Record 29 of Set 12 | zhezkazgan
# Processing Record 30 of Set 12 | andenes
# Processing Record 31 of Set 12 | burica
# City not found. Skipping...
# Processing Record 32 of Set 12 | swan hill
# City not found. Skipping...
# Processing Record 33 of Set 12 | kaniama
# Processing Record 34 of Set 12 | tukrah
# Processing Record 35 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 36 of Set 12 | lerwick
# Processing Record 37 of Set 12 | aracati
# Processing Record 38 of Set 12 | julio de castilhos
# City not found. Skipping...
# Processing Record 39 of Set 12 | dunedin
# Processing Record 40 of Set 12 | dingle
# Processing Record 41 of Set 12 | tongren
# Processing Record 42 of Set 12 | broken hill
# City not found. Skipping...
# Processing Record 43 of Set 12 | pangnirtung
# Processing Record 44 of Set 12 | timmins
# Processing Record 45 of Set 12 | high level
# City not found. Skipping...
# Processing Record 46 of Set 12 | yining
# Processing Record 47 of Set 12 | luziania
# Processing Record 48 of Set 12 | kutum
# Processing Record 49 of Set 12 | zapolyarnyy
# Processing Record 50 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 13 | eydhafushi
# Processing Record 2 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 13 | guekedou
# City not found. Skipping...
# Processing Record 4 of Set 13 | matara
# Processing Record 5 of Set 13 | suzhou
# Processing Record 6 of Set 13 | linda
# Processing Record 7 of Set 13 | baiquan
# Processing Record 8 of Set 13 | virginia beach
# City not found. Skipping...
# Processing Record 9 of Set 13 | sydney
# Processing Record 10 of Set 13 | hanmer springs
# City not found. Skipping...
# Processing Record 11 of Set 13 | jacareacanga
# Processing Record 12 of Set 13 | at-bashi
# Processing Record 13 of Set 13 | okhotsk
# Processing Record 14 of Set 13 | shuyskoye
# Processing Record 15 of Set 13 | ranong
# Processing Record 16 of Set 13 | sola
# Processing Record 17 of Set 13 | bath
# Processing Record 18 of Set 13 | bilma
# Processing Record 19 of Set 13 | iskateley
# Processing Record 20 of Set 13 | aksehir
# Processing Record 21 of Set 13 | poum
# Processing Record 22 of Set 13 | sfantu gheorghe
# City not found. Skipping...
# Processing Record 23 of Set 13 | cam ranh
# City not found. Skipping...
# Processing Record 24 of Set 13 | bandar
# Processing Record 25 of Set 13 | rairangpur
# Processing Record 26 of Set 13 | champasak
# Processing Record 27 of Set 13 | itacare
# Processing Record 28 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 13 | pathein
# Processing Record 30 of Set 13 | ahuimanu
# Processing Record 31 of Set 13 | grand gaube
# City not found. Skipping...
# Processing Record 32 of Set 13 | padang
# Processing Record 33 of Set 13 | aasiaat
# Processing Record 34 of Set 13 | goderich
# Processing Record 35 of Set 13 | bayan
# Processing Record 36 of Set 13 | mitsamiouli
# Processing Record 37 of Set 13 | mabaruma
# Processing Record 38 of Set 13 | college
# Processing Record 39 of Set 13 | paray-le-monial
# Processing Record 40 of Set 13 | viedma
# Processing Record 41 of Set 13 | wamba
# Processing Record 42 of Set 13 | karratha
# Processing Record 43 of Set 13 | sayan
# Processing Record 44 of Set 13 | daru
# Processing Record 45 of Set 13 | cruzeiro do sul
# City not found. Skipping...
# Processing Record 46 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 13 | ipira
# Processing Record 48 of Set 13 | broome
# Processing Record 49 of Set 13 | kalabo
# Processing Record 50 of Set 13 | maraa
# Processing Record 1 of Set 14 | ulu-telyak
# Processing Record 2 of Set 14 | tilichiki
# Processing Record 3 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 4 of Set 14 | balabac
# Processing Record 5 of Set 14 | jaguaribe
# Processing Record 6 of Set 14 | newport
# Processing Record 7 of Set 14 | sucua
# Processing Record 8 of Set 14 | maceio
# Processing Record 9 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 14 | garden city
# City not found. Skipping...
# Processing Record 11 of Set 14 | sioux lookout
# City not found. Skipping...
# Processing Record 12 of Set 14 | belmonte
# Processing Record 13 of Set 14 | japura
# Processing Record 14 of Set 14 | abu samrah
# City not found. Skipping...
# Processing Record 15 of Set 14 | kenora
# Processing Record 16 of Set 14 | groningen
# Processing Record 17 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 14 | nagutskoye
# Processing Record 19 of Set 14 | baruun-urt
# Processing Record 20 of Set 14 | exokhi
# City not found. Skipping...
# Processing Record 21 of Set 14 | mackenzie
# Processing Record 22 of Set 14 | pemangkat
# Processing Record 23 of Set 14 | zhigansk
# Processing Record 24 of Set 14 | ouegoa
# Processing Record 25 of Set 14 | sawakin
# Processing Record 26 of Set 14 | kabwe
# Processing Record 27 of Set 14 | negara
# Processing Record 28 of Set 14 | saint anthony
# City not found. Skipping...
# Processing Record 29 of Set 14 | rio grande
# Processing Record 30 of Set 14 | macenta
# Processing Record 31 of Set 14 | kemin
# Processing Record 32 of Set 14 | tura
# Processing Record 33 of Set 14 | atbasar
# Processing Record 34 of Set 14 | camocim
# Processing Record 35 of Set 14 | san jose de guanipa
# City not found. Skipping...
# Processing Record 36 of Set 14 | salinas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 530

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_cols = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_cols]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Bredasdorp      ZA -34.53   20.04     44.60        81          16
# 1        Dikson      RU  73.51   80.55     41.88        97         100
# 2    Hutchinson      US  38.06  -97.93     89.01        45          75
# 3      Victoria      HK  22.29  114.16     82.00        83          50
# 4  Constitucion      CL -35.33  -72.42     52.45        68           0
# 5     Bonavista      CA  48.65  -53.11     57.00        79          97
# 6    Butaritari      KI   3.07  172.79     83.01        71          17
# 7     Namatanai      PG  -3.67  152.43     82.31        78          34
# 8      Bilibino      RU  68.05  166.44     42.98        68         100
# 9         Bluff      NZ -46.60  168.33     54.19        62          53
#
#    Wind Speed Current Description
# 0        8.05          few clouds
# 1       15.21     overcast clouds
# 2        8.05       broken clouds
# 3        1.50          light rain
# 4       13.69           clear sky
# 5       16.58     overcast clouds
# 6       11.59          few clouds
# 7        9.04          light rain
# 8        5.21     overcast clouds
# 9       22.64       broken clouds

# %%
# Create the output file (CSV).
output_data_file = 'WeatherPy-database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
